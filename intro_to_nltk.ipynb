# %% [markdown]
# # Introduction to Natural Language Understanding using NLTK

# %%
import nltk
import pandas as pd 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Let us bring in the text file

# %%
passage = '''The quick brown fox jumps over the lazy dog is an English-language pangram a sentence that contains all the letters of the alphabet. The phrase is commonly used for touch-typing practice, testing typewriters and computer keyboards, displaying examples of fonts, and other applications involving text where the use of all letters in the alphabet is desired.
In the age of computers, this pangram is commonly used to display font samples and for testing computer keyboards. In cryptography, it is commonly used as a test vector for hash and encryption algorithms to verify their implementation, as well as to ensure alphabetic character set compatibility.
Microsoft Word has a command to auto-type the sentence, in versions up to Word 2003, and in Microsoft Office Word 2007 and later'''

# %% [markdown]
# ### Sentence Tokenisation
# Lets begin by breaking the passage into sentences

# %%
sentence_token = nltk.sent_tokenize(passage)

sentence_token
# Out:
# ['The quick brown fox jumps over the lazy dog is an English-language pangram a sentence that contains all the letters of the alphabet.',
#  'The phrase is commonly used for touch-typing practice, testing typewriters and computer keyboards, displaying examples of fonts, and other applications involving text where the use of all letters in the alphabet is desired.',
#  'In the age of computers, this pangram is commonly used to display font samples and for testing computer keyboards.',
#  'In cryptography, it is commonly used as a test vector for hash and encryption algorithms to verify their implementation, as well as to ensure alphabetic character set compatibility.',
#  'Microsoft Word has a command to auto-type the sentence, in versions up to Word 2003, and in Microsoft Office Word 2007 and later']

# %% [markdown]
# Lets do Word level tokenization

# %%
word_tokens = nltk.word_tokenize(passage)

word_tokens
# Out:
# ['The',
#  'quick',
#  'brown',
#  'fox',
#  'jumps',
#  'over',
#  'the',
#  'lazy',
#  'dog',
#  'is',
#  'an',
#  'English-language',
#  'pangram',
#  'a',
#  'sentence',
#  'that',
#  'contains',
#  'all',
#  'the',
#  'letters',
#  'of',
#  'the',
#  'alphabet',
#  '.',
#  'The',
#  'phrase',
#  'is',
#  'commonly',
#  'used',
#  'for',
#  'touch-typing',
#  'practice',
#  ',',
#  'testing',
#  'typewriters',
#  'and',
#  'computer',
#  'keyboards',
#  ',',
#  'displaying',
#  'examples',
#  'of',
#  'fonts',
#  ',',
#  'and',
#  'other',
#  'applications',
#  'involving',
#  'text',
#  'where',
#  'the',
#  'use',
#  'of',
#  'all',
#  'letters',
#  'in',
#  'the',
#  'alphabet',
#  'is',
#  'desired',
#  '.',
#  'In',
#  'the',
#  'age',
#  'of',
#  'computers',
#  ',',
#  'this',
#  'pangram',
#  'is',
#  'commonly',
#  'used',
#  'to',
#  'display',
#  'font',
#  'samples',
#  'and',
#  'for',
#  'testing',
#  'computer',
#  'keyboards',
#  '.',
#  'In',
#  'cryptography',
#  ',',
#  'it',
#  'is',
#  'commonly',
#  'used',
#  'as',
#  'a',
#  'test',
#  'vector',
#  'for',
#  'hash',
#  'and',
#  'encryption',
#  'algorithms',
#  'to',
#  'verify',
#  'their',
#  'implementation',
#  ',',
#  'as',
#  'well',
#  'as',
#  'to',
#  'ensure',
#  'alphabetic',
#  'character',
#  'set',
#  'compatibility',
#  '.',
#  'Microsoft',
#  'Word',
#  'has',
#  'a',
#  'command',
#  'to',
#  'auto-type',
#  'the',
#  'sentence',
#  ',',
#  'in',
#  'versions',
#  'up',
#  'to',
#  'Word',
#  '2003',
#  ',',
#  'and',
#  'in',
#  'Microsoft',
#  'Office',
#  'Word',
#  '2007',
#  'and',
#  'later']

# %% [markdown]
# Lets do the Parts of Speech tagging

# %%
pos_tagged = nltk.pos_tag(word_tokens)
pos_tagged[0:9]
# Out:
# [('The', 'DT'),
#  ('quick', 'JJ'),
#  ('brown', 'NN'),
#  ('fox', 'NN'),
#  ('jumps', 'VBZ'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('lazy', 'JJ'),
#  ('dog', 'NN')]

# %% [markdown]
# Identifying the named entities

# %%
named_entities = nltk.ne_chunk(pos_tagged)
named_entities
# Out:
# Tree('S', [('The', 'DT'), ('quick', 'JJ'), ('brown', 'NN'), ('fox', 'NN'), ('jumps', 'VBZ'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('English-language', 'JJ'), ('pangram', 'NN'), ('a', 'DT'), ('sentence', 'NN'), ('that', 'WDT'), ('contains', 'VBZ'), ('all', 'PDT'), ('the', 'DT'), ('letters', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('alphabet', 'NN'), ('.', '.'), ('The', 'DT'), ('phrase', 'NN'), ('is', 'VBZ'), ('commonly', 'RB'), ('used', 'VBN'), ('for', 'IN'), ('touch-typing', 'JJ'), ('practice', 'NN'), (',', ','), ('testing', 'VBG'), ('typewriters', 'NNS'), ('and', 'CC'), ('computer', 'NN'), ('keyboards', 'NNS'), (',', ','), ('displaying', 'VBG'), ('examples', 'NNS'), ('of', 'IN'), ('fonts', 'NNS'), (',', ','), ('and', 'CC'), ('other', 'JJ'), ('applications', 'NNS'), ('involving', 'VBG'), ('text', 'NN'), ('where', 'WRB'), ('the', 'DT'), ('use', 'NN'), ('of', 'IN'), ('all', 'DT'), ('letters', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('alphabet', 'NN'), ('is', 'VBZ'), ('desired', 'VBN'), ('.', '.'), ('In', 'IN'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('computers', 'NNS'), (',', ','), ('this', 'DT'), ('pangram', 'NN'), ('is', 'VBZ'), ('commonly', 'RB'), ('used', 'VBN'), ('to', 'TO'), ('display', 'VB'), ('font', 'JJ'), ('samples', 'NNS'), ('and', 'CC'), ('for', 'IN'), ('testing', 'VBG'), ('computer', 'NN'), ('keyboards', 'NNS'), ('.', '.'), ('In', 'IN'), ('cryptography', 'NN'), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('commonly', 'RB'), ('used', 'VBN'), ('as', 'IN'), ('a', 'DT'), ('test', 'NN'), ('vector', 'NN'), ('for', 'IN'), ('hash', 'NN'), ('and', 'CC'), ('encryption', 'NN'), ('algorithms', 'NN'), ('to', 'TO'), ('verify', 'VB'), ('their', 'PRP$'), ('implementation', 'NN'), (',', ','), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('to', 'TO'), ('ensure', 'VB'), ('alphabetic', 'JJ'), ('character', 'NN'), ('set', 'VBN'), ('compatibility', 'NN'), ('.', '.'), Tree('PERSON', [('Microsoft', 'NNP'), ('Word', 'NNP')]), ('has', 'VBZ'), ('a', 'DT'), ('command', 'NN'), ('to', 'TO'), ('auto-type', 'VB'), ('the', 'DT'), ('sentence', 'NN'), (',', ','), ('in', 'IN'), ('versions', 'NNS'), ('up', 'IN'), ('to', 'TO'), ('Word', 'NNP'), ('2003', 'CD'), (',', ','), ('and', 'CC'), ('in', 'IN'), Tree('ORGANIZATION', [('Microsoft', 'NNP')]), ('Office', 'NNP'), ('Word', 'NNP'), ('2007', 'CD'), ('and', 'CC'), ('later', 'RB')])

# %% [markdown]
# ### To import and draw the treebank

# %%
from nltk.corpus import treebank

# %%
# load the treebank
tree_corpus = treebank.parsed_sents('wsj_0001.mrg')

# Access the first message
t = tree_corpus[0]

# Now, draw the tree
t.draw()
